# %% [markdown]
# ## Download Data from Kaggle

# %%
from googleapiclient.discovery import build
import io, os
from googleapiclient.http import MediaIoBaseDownload
from google.colab import auth

auth.authenticate_user()

drive_service = build('drive', 'v3')
results = drive_service.files().list(
        q="name = 'kaggle.json'", fields="files(id)").execute()
kaggle_api_key = results.get('files', [])

filename = "/content/.kaggle/kaggle.json"
os.makedirs(os.path.dirname(filename), exist_ok=True)

request = drive_service.files().get_media(fileId=kaggle_api_key[0]['id'])
fh = io.FileIO(filename, 'wb')
downloader = MediaIoBaseDownload(fh, request)
done = False
while done is False:
    status, done = downloader.next_chunk()
    print("Download %d%%." % int(status.progress() * 100))
os.chmod(filename, 600)
# Out:
# W0817 12:57:32.277158 140053279844224 __init__.py:44] file_cache is unavailable when using oauth2client >= 4.0.0 or google-auth
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/googleapiclient/discovery_cache/__init__.py", line 36, in autodetect
#     from google.appengine.api import memcache
# ModuleNotFoundError: No module named 'google.appengine'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/googleapiclient/discovery_cache/file_cache.py", line 33, in <module>
#     from oauth2client.contrib.locked_file import LockedFile
# ModuleNotFoundError: No module named 'oauth2client.contrib.locked_file'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/googleapiclient/discovery_cache/file_cache.py", line 37, in <module>
#     from oauth2client.locked_file import LockedFile
# ModuleNotFoundError: No module named 'oauth2client.locked_file'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/googleapiclient/discovery_cache/__init__.py", line 41, in autodetect
#     from . import file_cache
#   File "/usr/local/lib/python3.6/dist-packages/googleapiclient/discovery_cache/file_cache.py", line 41, in <module>
#     'file_cache is unavailable when using oauth2client >= 4.0.0 or google-auth')
# ImportError: file_cache is unavailable when using oauth2client >= 4.0.0 or google-auth
# W0817 12:57:32.300254 140053279844224 _default.py:280] No project ID could be determined. Consider running `gcloud config set project` or setting the GOOGLE_CLOUD_PROJECT environment variable
# Download 100%.

# %%
# !mkdir ~/.kaggle
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists

# %%
# !cp /content/.kaggle/kaggle.json ~/.kaggle/kaggle.json

# %%
# !kaggle competitions download -c ml-marathon-final
# Out:
# sample_submission.csv: Skipping, found more recently modified local copy (use --force to force download)
# data.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
# !ls
# Out:
# adc.json  kaggle_dogcat		sample_data
# data.zip  kochifinal_exam.hdf5	sample_submission.csv

# %%
import zipfile

zip_ref = zipfile.ZipFile('data.zip', 'r')
zip_ref.extractall()
zip_ref.close()

# %%
# !ls
# Out:
# adc.json  kaggle_dogcat		sample_data
# data.zip  kochifinal_exam.hdf5	sample_submission.csv

# %% [markdown]
# #Preprocess Images

# %%
import numpy as np 
import pandas as pd 
import os
train_dir = "./kaggle_dogcat/train/"
test_dir =  "./kaggle_dogcat/test/"

# Load all the filenames (Actually we can use "flow_from_directory" function
# from ImageDataGenerator to load the image, in case the momory is tight)
train_dog_fns = os.listdir(train_dir + "dogs/")
train_cat_fns = os.listdir(train_dir + "cats/")
test_fns = os.listdir(test_dir)

#############################################################
#############################################################
#Dont forget to sort the file name for matching submission ID
test_fns.sort()
#############################################################
############################################################

# Check the legnth of all data first
print(f"dog images in training set : {len(train_dog_fns)}")
print(f"cat images in training set : {len(train_cat_fns)}")
print(f"total images in test set : {len(test_fns)}")
# Out:
# dog images in training set : 2000
# cat images in training set : 2000
# total images in test set : 400

# %%
target_size = (64,64,3)

# %%
from keras.preprocessing.image import ImageDataGenerator, load_img
from sklearn.utils import shuffle
import matplotlib.pyplot as plt

#This two array is for channel-base mean subtraction preprocessing
#although my score had became worse after using it. 
#pre-calculated mean value of each channel of training  dataset
#Pre-calculate std values of each channel of training dataset
train_mean = np.array([0.4914, 0.458, 0.4193], dtype = 'float64')
train_std = np.array([0.2591,0.2524,0.25511] , dtype = 'float64')

def load_target_img(grayscale = False, color_mode = 'rgb'
                    , target_size = target_size, interpolation = 'bicubic'):
    '''
    grayscale : loading image with color type or grayscale type
    color_mode : loading image with rgb color space and the channels are (r,g,b)
    target_size :Image will be rescale/resize to the target size when loading
    interpolation : the interpolation algorithm for rescaling/resizing the image, nearest is the most simplest and fastest one 
    '''
    def f(path):
        return load_img(path = path, grayscale = grayscale, color_mode = color_mode,
                              target_size = target_size, interpolation=interpolation)
    return f

# I created an image generator to generate the image in batch size
# In case the momery is not enough

def image_generator(load_dir, dog_fns, cat_fns, batch_size = 32):
    '''
    load_dir : data loading path
    dog_fns : filenames of dog picture
    cat_fns : filenames of cat picture
    batch_size : how many data we package as a batch
    '''
    dog_load_dir = load_dir + "dogs/"
    cat_load_dir = load_dir + "cats/"
    data_batch = []
    label_batch = []
    
    while True:
        for idx in range(min(len(dog_fns),len(cat_fns))):
            
            # We should check the file is .jpg format or not
            if ".jpg" in dog_fns[idx] and ".jpg" in cat_fns[idx]:
                data_batch.append( np.asarray(load_target_img()(dog_load_dir + dog_fns[idx])) ) 
                label_batch.append([1,0]) # setting dog label to 0
                data_batch.append( np.asarray(load_target_img()(cat_load_dir + cat_fns[idx])) )
                label_batch.append([0,1]) # setting cat label to 1
                    
                # When the batch collecting is reach to batch_size
                # The data is ready to shipping out
                # yield can keep the status of your function 
                if len(data_batch) >= batch_size :
                    yield np.stack(data_batch), np.stack(label_batch)
                    data_batch = []
                    label_batch = []
                
def image_augmentation_generator(input_gen, image_gen):
    '''
    input_gen : input image generator, it will generate a batch of data a time
    image_gen : ImageDataGenerator from keras
    '''
    for data, label in input_gen:
        
        data,label = shuffle(data, label, random_state = np.random.choice(2019,1)[0])
        
        #We need to recover the original depth of image before augmentation
        #Since the augmentation process is based on normal image depth(8 bits, 0-255)
        x = image_gen.flow(data, batch_size = data.shape[0], shuffle = False)
        y = label
        
        #Dont forget to normalize the image back after done aumentation processing
        yield next(x), y
        

        
#Since the test dataset is small (only 400 pictures), so I decided to read all of them into RAM
test_x = []
for fn in test_fns:
    if ".jpg" in fn:
        test_x.append(np.asarray(load_target_img()(test_dir + fn)))

#dont forget to normalize the data
test_x = np.asarray(test_x, dtype = 'float64') / 255.0
test_x.shape
# Out:
# (400, 32, 32, 3)

# %%
#split the training dataset and validation dataset
train_dog_fns, valid_dog_fns = train_dog_fns[:1800], train_dog_fns[1800:]
train_cat_fns, valid_cat_fns = train_cat_fns[:1800], train_cat_fns[1800:]

# %%
batch_size = 64

# %%
train_input_gen = image_generator(train_dir, train_dog_fns, train_cat_fns,batch_size)
valid_input_gen = image_generator(train_dir, valid_dog_fns, valid_cat_fns,batch_size)

train_image_gen = ImageDataGenerator(
            rotation_range = 40,
            shear_range = 0.2,
            width_shift_range = 0.2,
            height_shift_range = 0.2,
            zoom_range = 0.2,
            horizontal_flip = True,
            rescale = 1.0/255.0
            )

valid_image_gen = ImageDataGenerator( rescale = 1.0/255.0 )

train_aug_gen = image_augmentation_generator(train_input_gen, train_image_gen)
valid_aug_gen = image_augmentation_generator(valid_input_gen, valid_image_gen)

# %%
#Use next to get one batch of data and label
batch_data, batch_label = next(valid_aug_gen)
print(f"batch data shape : {batch_data.shape}")
print(f"batch label shape : {batch_label.shape}")

plt.figure(figsize = (12,8))
nrow = 2
ncol = 4

for i in range(nrow*ncol):
    img = batch_data[i]
    label = batch_label[i]
    plt.subplot(nrow,ncol,i+1)
    plt.title(f"Label : {label}")
    plt.axis('off')
    plt.imshow(img)
plt.show()
# Out:
# batch data shape : (64, 32, 32, 3)
# batch label shape : (64, 2)

# %% [markdown]
# ## Build CNN Model

# %%
import keras
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization
from keras.optimizers import Adam, RMSprop
from keras.callbacks import ModelCheckpoint, Callback, EarlyStopping

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

weight_saving_path = "kochifinal_exam.hdf5"

#ModelCheckpoint will keep monitor your monitor item, and it will save the weight automatically
#when the monitor item is imporved
checkpoint = ModelCheckpoint(weight_saving_path, monitor = "val_loss", verbose = 1,
                            save_best_only = True, mode = "min")

#ReduceLROnPlateau will reduce your learning rate if the monitor item was not improve in patience times.
reduce_lr = ReduceLROnPlateau(monitor = "val_loss", verbose = 1, mode = "min", patience = 5,
                             factor = 0.5, min_lr = 1e-8)

#EarlyStopping will stop the training if the monitor item was not improve in patience times.
ES = EarlyStopping(monitor = "val_loss", patience = 10, mode = "min", verbose = 1)

training_callbacks = [checkpoint, ES]

# %%
def build_CNN(input_shape):
  
  input_layer = keras.layers.Input(test_x.shape[1:])
  
  x = Conv2D(filters = 32, kernel_size = (3,3), padding = 'same')(input_layer)
  x = BatchNormalization()(x)
  x = Activation('relu')(x)
  x = Conv2D(filters = 32, kernel_size = (3,3), padding = 'same')(x)
  x = BatchNormalization()(x)
  x = Activation('relu')(x)
  x = MaxPooling2D(pool_size = (2,2))(x)
  x = Dropout(0.25)(x)
  
  x = Conv2D(filters = 64, kernel_size = (3,3), padding = 'same')(x)
  x = BatchNormalization()(x)
  x = Activation('relu')(x)
  x = Conv2D(filters = 64, kernel_size = (3,3), padding = 'same')(x)
  x = BatchNormalization()(x)
  x = Activation('relu')(x)
  x = MaxPooling2D(pool_size = (2,2))(x)
  x = Dropout(0.25)(x)
  
  x = Conv2D(filters = 128, kernel_size = (3,3), padding = 'same')(x)
  x = BatchNormalization()(x)
  x = Activation('relu')(x)
  x = Conv2D(filters = 128, kernel_size = (3,3), padding = 'same')(x)
  x = BatchNormalization()(x)
  x = Activation('relu')(x)
  x = MaxPooling2D(pool_size = (2,2))(x)
  x = Dropout(0.25)(x)
  
  x = Flatten()(x)
  x = Dense(units = 512)(x)
  x = BatchNormalization()(x)
  x = Activation('relu')(x)
  x = Dropout(0.25)(x)
  
  x = Dense(units = 256)(x)
  x = BatchNormalization()(x)
  x = Activation('relu')(x)
  x = Dropout(0.25)(x)
  
  x = Dense(units = 128)(x)
  x = BatchNormalization()(x)
  x = Activation('relu')(x)
  x = Dropout(0.25)(x)
  
  output_layer = Dense(units = 2, activation = "softmax")(x)
  
  model = keras.models.Model( inputs = [input_layer], outputs = [output_layer])
  
  return model

# %%
epochs = 100

# %%
cnn_model = build_CNN(target_size)
cnn_model.summary()     


optimizer = keras.optimizers.Adam(lr = 1e-4, decay = 1e-6)
cnn_model.compile(loss = "categorical_crossentropy", metrics = ['accuracy'], optimizer = optimizer)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         (None, 32, 32, 3)         0
# _________________________________________________________________
# conv2d_31 (Conv2D)           (None, 32, 32, 32)        896
# _________________________________________________________________
# batch_normalization_46 (Batc (None, 32, 32, 32)        128
# _________________________________________________________________
# activation_46 (Activation)   (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_32 (Conv2D)           (None, 32, 32, 32)        9248
# _________________________________________________________________
# batch_normalization_47 (Batc (None, 32, 32, 32)        128
# _________________________________________________________________
# activation_47 (Activation)   (None, 32, 32, 32)        0
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 16, 16, 32)        0
# _________________________________________________________________
# dropout_31 (Dropout)         (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_33 (Conv2D)           (None, 16, 16, 64)        18496
# _________________________________________________________________
# batch_normalization_48 (Batc (None, 16, 16, 64)        256
# _________________________________________________________________
# activation_48 (Activation)   (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_34 (Conv2D)           (None, 16, 16, 64)        36928
# _________________________________________________________________
# batch_normalization_49 (Batc (None, 16, 16, 64)        256
# _________________________________________________________________
# activation_49 (Activation)   (None, 16, 16, 64)        0
# _________________________________________________________________
# max_pooling2d_17 (MaxPooling (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_32 (Dropout)         (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_35 (Conv2D)           (None, 8, 8, 128)         73856
# _________________________________________________________________
# batch_normalization_50 (Batc (None, 8, 8, 128)         512
# _________________________________________________________________
# activation_50 (Activation)   (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_36 (Conv2D)           (None, 8, 8, 128)         147584
# _________________________________________________________________
# batch_normalization_51 (Batc (None, 8, 8, 128)         512
# _________________________________________________________________
# activation_51 (Activation)   (None, 8, 8, 128)         0
# _________________________________________________________________
# max_pooling2d_18 (MaxPooling (None, 4, 4, 128)         0
# _________________________________________________________________
# dropout_33 (Dropout)         (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_21 (Dense)             (None, 512)               1049088
# _________________________________________________________________
# batch_normalization_52 (Batc (None, 512)               2048
# _________________________________________________________________
# activation_52 (Activation)   (None, 512)               0
# _________________________________________________________________
# dropout_34 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_22 (Dense)             (None, 256)               131328
# _________________________________________________________________
# batch_normalization_53 (Batc (None, 256)               1024
# _________________________________________________________________
# activation_53 (Activation)   (None, 256)               0
# _________________________________________________________________
# dropout_35 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_23 (Dense)             (None, 128)               32896
# _________________________________________________________________
# batch_normalization_54 (Batc (None, 128)               512
# _________________________________________________________________
# activation_54 (Activation)   (None, 128)               0
# _________________________________________________________________
# dropout_36 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_24 (Dense)             (None, 2)                 258
# =================================================================
# Total params: 1,505,954
# Trainable params: 1,503,266
# Non-trainable params: 2,688
# _________________________________________________________________

# %%
history = cnn_model.fit_generator(train_aug_gen, epochs = epochs, verbose =1, validation_data = valid_aug_gen , validation_steps = (len(valid_dog_fns) + len(valid_cat_fns))//batch_size,
                                steps_per_epoch = (len(train_dog_fns)+len(train_cat_fns))//batch_size, callbacks = training_callbacks)
# Out:
# Epoch 1/100
# 56/56 [==============================] - 53s 954ms/step - loss: 0.8273 - acc: 0.5290 - val_loss: 0.7977 - val_acc: 0.5651
#
# Epoch 00001: val_loss improved from inf to 0.79771, saving model to kochifinal_exam.hdf5
# Epoch 2/100
# 56/56 [==============================] - 47s 830ms/step - loss: 0.7298 - acc: 0.5631 - val_loss: 0.7887 - val_acc: 0.6016
#
# Epoch 00002: val_loss improved from 0.79771 to 0.78867, saving model to kochifinal_exam.hdf5
# Epoch 3/100
# 56/56 [==============================] - 46s 825ms/step - loss: 0.6856 - acc: 0.5926 - val_loss: 0.7922 - val_acc: 0.5990
#
# Epoch 00003: val_loss did not improve from 0.78867
# Epoch 4/100
# 56/56 [==============================] - 46s 827ms/step - loss: 0.6573 - acc: 0.6306 - val_loss: 0.9397 - val_acc: 0.5807
#
# Epoch 00004: val_loss did not improve from 0.78867
# Epoch 5/100
# 56/56 [==============================] - 46s 827ms/step - loss: 0.6387 - acc: 0.6409 - val_loss: 0.7610 - val_acc: 0.5859
#
# Epoch 00005: val_loss improved from 0.78867 to 0.76095, saving model to kochifinal_exam.hdf5
# Epoch 6/100
# 56/56 [==============================] - 46s 822ms/step - loss: 0.6407 - acc: 0.6448 - val_loss: 0.7860 - val_acc: 0.5807
#
# Epoch 00006: val_loss did not improve from 0.76095
# Epoch 7/100
# 56/56 [==============================] - 46s 829ms/step - loss: 0.6269 - acc: 0.6557 - val_loss: 0.6618 - val_acc: 0.6615
#
# Epoch 00007: val_loss improved from 0.76095 to 0.66180, saving model to kochifinal_exam.hdf5
# Epoch 8/100
# 56/56 [==============================] - 46s 824ms/step - loss: 0.6227 - acc: 0.6554 - val_loss: 0.7082 - val_acc: 0.6042
#
# Epoch 00008: val_loss did not improve from 0.66180
# Epoch 9/100
# 56/56 [==============================] - 46s 829ms/step - loss: 0.6102 - acc: 0.6691 - val_loss: 0.6391 - val_acc: 0.6615
#
# Epoch 00009: val_loss improved from 0.66180 to 0.63908, saving model to kochifinal_exam.hdf5
# Epoch 10/100
# 56/56 [==============================] - 46s 830ms/step - loss: 0.5943 - acc: 0.6825 - val_loss: 0.5812 - val_acc: 0.6849
#
# Epoch 00010: val_loss improved from 0.63908 to 0.58122, saving model to kochifinal_exam.hdf5
# Epoch 11/100
# 56/56 [==============================] - 47s 836ms/step - loss: 0.5878 - acc: 0.6797 - val_loss: 0.6186 - val_acc: 0.6484
#
# Epoch 00011: val_loss did not improve from 0.58122
# Epoch 12/100
# 56/56 [==============================] - 47s 831ms/step - loss: 0.5845 - acc: 0.6925 - val_loss: 0.5679 - val_acc: 0.7083
#
# Epoch 00012: val_loss improved from 0.58122 to 0.56791, saving model to kochifinal_exam.hdf5
# Epoch 13/100
# 56/56 [==============================] - 47s 832ms/step - loss: 0.5745 - acc: 0.7015 - val_loss: 0.6249 - val_acc: 0.6797
#
# Epoch 00013: val_loss did not improve from 0.56791
# Epoch 14/100
# 56/56 [==============================] - 47s 832ms/step - loss: 0.5603 - acc: 0.7012 - val_loss: 0.7722 - val_acc: 0.5964
#
# Epoch 00014: val_loss did not improve from 0.56791
# Epoch 15/100
# 56/56 [==============================] - 46s 829ms/step - loss: 0.5641 - acc: 0.7048 - val_loss: 0.6312 - val_acc: 0.5990
#
# Epoch 00015: val_loss did not improve from 0.56791
# Epoch 16/100
# 56/56 [==============================] - 46s 829ms/step - loss: 0.5625 - acc: 0.7123 - val_loss: 0.5630 - val_acc: 0.6849
#
# Epoch 00016: val_loss improved from 0.56791 to 0.56298, saving model to kochifinal_exam.hdf5
# Epoch 17/100
# 56/56 [==============================] - 47s 841ms/step - loss: 0.5509 - acc: 0.7090 - val_loss: 0.6653 - val_acc: 0.6797
#
# Epoch 00017: val_loss did not improve from 0.56298
# Epoch 18/100
# 56/56 [==============================] - 47s 838ms/step - loss: 0.5544 - acc: 0.7190 - val_loss: 0.5729 - val_acc: 0.6901
#
# Epoch 00018: val_loss did not improve from 0.56298
# Epoch 19/100
# 56/56 [==============================] - 47s 839ms/step - loss: 0.5440 - acc: 0.7218 - val_loss: 0.6260 - val_acc: 0.6536
#
# Epoch 00019: val_loss did not improve from 0.56298
# Epoch 20/100
# 56/56 [==============================] - 47s 837ms/step - loss: 0.5435 - acc: 0.7260 - val_loss: 0.5765 - val_acc: 0.7344
#
# Epoch 00020: val_loss did not improve from 0.56298
# Epoch 21/100
# 56/56 [==============================] - 47s 839ms/step - loss: 0.5420 - acc: 0.7235 - val_loss: 0.5559 - val_acc: 0.7240
#
# Epoch 00021: val_loss improved from 0.56298 to 0.55594, saving model to kochifinal_exam.hdf5
# Epoch 22/100
# 56/56 [==============================] - 47s 842ms/step - loss: 0.5289 - acc: 0.7347 - val_loss: 0.5843 - val_acc: 0.6771
#
# Epoch 00022: val_loss did not improve from 0.55594
# Epoch 23/100
# 56/56 [==============================] - 47s 842ms/step - loss: 0.5288 - acc: 0.7335 - val_loss: 0.5721 - val_acc: 0.7109
#
# Epoch 00023: val_loss did not improve from 0.55594
# Epoch 24/100
# 56/56 [==============================] - 47s 838ms/step - loss: 0.5212 - acc: 0.7419 - val_loss: 0.5071 - val_acc: 0.7422
#
# Epoch 00024: val_loss improved from 0.55594 to 0.50712, saving model to kochifinal_exam.hdf5
# Epoch 25/100
# 56/56 [==============================] - 47s 840ms/step - loss: 0.5075 - acc: 0.7439 - val_loss: 0.5847 - val_acc: 0.7109
#
# Epoch 00025: val_loss did not improve from 0.50712
# Epoch 26/100
# 56/56 [==============================] - 47s 836ms/step - loss: 0.5245 - acc: 0.7338 - val_loss: 0.6945 - val_acc: 0.6641
#
# Epoch 00026: val_loss did not improve from 0.50712
# Epoch 27/100
# 56/56 [==============================] - 47s 841ms/step - loss: 0.5061 - acc: 0.7447 - val_loss: 0.5333 - val_acc: 0.7422
#
# Epoch 00027: val_loss did not improve from 0.50712
# Epoch 28/100
# 56/56 [==============================] - 47s 840ms/step - loss: 0.4961 - acc: 0.7584 - val_loss: 0.5885 - val_acc: 0.7109
#
# Epoch 00028: val_loss did not improve from 0.50712
# Epoch 29/100
# 56/56 [==============================] - 47s 840ms/step - loss: 0.5142 - acc: 0.7461 - val_loss: 0.6978 - val_acc: 0.6693
#
# Epoch 00029: val_loss did not improve from 0.50712
# Epoch 30/100
# 56/56 [==============================] - 47s 845ms/step - loss: 0.4892 - acc: 0.7628 - val_loss: 0.5058 - val_acc: 0.7526
#
# Epoch 00030: val_loss improved from 0.50712 to 0.50577, saving model to kochifinal_exam.hdf5
# Epoch 31/100
# 56/56 [==============================] - 47s 845ms/step - loss: 0.5023 - acc: 0.7486 - val_loss: 0.5468 - val_acc: 0.7396
#
# Epoch 00031: val_loss did not improve from 0.50577
# Epoch 32/100
# 56/56 [==============================] - 47s 841ms/step - loss: 0.4890 - acc: 0.7553 - val_loss: 0.4798 - val_acc: 0.7891
#
# Epoch 00032: val_loss improved from 0.50577 to 0.47977, saving model to kochifinal_exam.hdf5
# Epoch 33/100
# 56/56 [==============================] - 47s 841ms/step - loss: 0.4855 - acc: 0.7667 - val_loss: 0.5630 - val_acc: 0.7292
#
# Epoch 00033: val_loss did not improve from 0.47977
# Epoch 34/100
# 56/56 [==============================] - 47s 837ms/step - loss: 0.4913 - acc: 0.7528 - val_loss: 0.5123 - val_acc: 0.7630
#
# Epoch 00034: val_loss did not improve from 0.47977
# Epoch 35/100
# 56/56 [==============================] - 47s 839ms/step - loss: 0.4727 - acc: 0.7679 - val_loss: 0.4782 - val_acc: 0.7865
#
# Epoch 00035: val_loss improved from 0.47977 to 0.47819, saving model to kochifinal_exam.hdf5
# Epoch 36/100
# 56/56 [==============================] - 47s 835ms/step - loss: 0.4673 - acc: 0.7759 - val_loss: 0.4770 - val_acc: 0.7865
#
# Epoch 00036: val_loss improved from 0.47819 to 0.47698, saving model to kochifinal_exam.hdf5
# Epoch 37/100
# 56/56 [==============================] - 47s 846ms/step - loss: 0.4775 - acc: 0.7695 - val_loss: 0.4926 - val_acc: 0.7812
#
# Epoch 00037: val_loss did not improve from 0.47698
# Epoch 38/100
# 56/56 [==============================] - 47s 838ms/step - loss: 0.4608 - acc: 0.7768 - val_loss: 0.4351 - val_acc: 0.7943
#
# Epoch 00038: val_loss improved from 0.47698 to 0.43509, saving model to kochifinal_exam.hdf5
# Epoch 39/100
# 56/56 [==============================] - 47s 837ms/step - loss: 0.4680 - acc: 0.7748 - val_loss: 0.4624 - val_acc: 0.7734
#
# Epoch 00039: val_loss did not improve from 0.43509
# Epoch 40/100
# 56/56 [==============================] - 47s 836ms/step - loss: 0.4654 - acc: 0.7757 - val_loss: 0.7631 - val_acc: 0.6406
#
# Epoch 00040: val_loss did not improve from 0.43509
# Epoch 41/100
# 56/56 [==============================] - 47s 842ms/step - loss: 0.4534 - acc: 0.7821 - val_loss: 0.4833 - val_acc: 0.7734
#
# Epoch 00041: val_loss did not improve from 0.43509
# Epoch 42/100
# 56/56 [==============================] - 47s 835ms/step - loss: 0.4492 - acc: 0.7826 - val_loss: 0.4701 - val_acc: 0.7839
#
# Epoch 00042: val_loss did not improve from 0.43509
# Epoch 43/100
# 56/56 [==============================] - 47s 839ms/step - loss: 0.4557 - acc: 0.7843 - val_loss: 0.7574 - val_acc: 0.6484
#
# Epoch 00043: val_loss did not improve from 0.43509
# Epoch 44/100
# 56/56 [==============================] - 47s 844ms/step - loss: 0.4382 - acc: 0.7927 - val_loss: 0.5879 - val_acc: 0.6979
#
# Epoch 00044: val_loss did not improve from 0.43509
# Epoch 45/100
# 56/56 [==============================] - 47s 841ms/step - loss: 0.4594 - acc: 0.7793 - val_loss: 0.4624 - val_acc: 0.7656
#
# Epoch 00045: val_loss did not improve from 0.43509
# Epoch 46/100
# 56/56 [==============================] - 47s 834ms/step - loss: 0.4474 - acc: 0.7902 - val_loss: 0.5067 - val_acc: 0.7604
#
# Epoch 00046: val_loss did not improve from 0.43509
# Epoch 47/100
# 56/56 [==============================] - 47s 836ms/step - loss: 0.4319 - acc: 0.7966 - val_loss: 0.5028 - val_acc: 0.7630
#
# Epoch 00047: val_loss did not improve from 0.43509
# Epoch 48/100
# 56/56 [==============================] - 47s 837ms/step - loss: 0.4280 - acc: 0.7985 - val_loss: 0.5686 - val_acc: 0.7266
#
# Epoch 00048: val_loss did not improve from 0.43509
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-64-aa6e7c7c8792> in <module>()
#       1 history = cnn_model.fit_generator(train_aug_gen, epochs = epochs, verbose =1, validation_data = valid_aug_gen , validation_steps = (len(valid_dog_fns) + len(valid_cat_fns))//batch_size,
# ----> 2                                 steps_per_epoch = (len(train_dog_fns)+len(train_cat_fns))//batch_size, callbacks = training_callbacks)
#
# /usr/local/lib/python3.6/dist-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1416             use_multiprocessing=use_multiprocessing,
#    1417             shuffle=shuffle,
# -> 1418             initial_epoch=initial_epoch)
#    1419
#    1420     @interfaces.legacy_generator_methods_support
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     262                 val_enqueuer.stop()
#     263
# --> 264     callbacks.on_train_end()
#     265     return model.history
#     266
#
# /usr/local/lib/python3.6/dist-packages/keras/callbacks.py in on_train_end(self, logs)
#     140         logs = logs or {}
#     141         for callback in self.callbacks:
# --> 142             callback.on_train_end(logs)
#     143
#     144     def __iter__(self):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/callbacks.py in on_train_end(self, logs)
#     938     logs = logs or {}
#     939     # pylint: disable=protected-access
# --> 940     if self.model._ckpt_saved_epoch is not None:
#     941       # Make `_ckpt_saved_epoch` attribute `None` at the end of training as it
#     942       # is only used during the training. Currently it is decided not to
#
# AttributeError: 'Model' object has no attribute '_ckpt_saved_epoch'

# %%
cnn_model.load_weights('kochifinal_exam.hdf5')

# %%
plt.figure(figsize = (8,6))
plt.plot(history.history['loss'], label = 'train_loss')
plt.plot(history.history['val_loss'], label = 'valid_loss')
plt.title("Loss of model on Dogs and Cats classification")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

plt.figure(figsize = (8,6))
plt.plot(history.history['acc'], label = 'train_acc')
plt.plot(history.history['val_acc'], label = 'valid_acc')
plt.title("Accuracy of model on Dogs and Cats classification")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-66-04f17003b18b> in <module>()
#       1 plt.figure(figsize = (8,6))
# ----> 2 plt.plot(history.history['loss'], label = 'train_loss')
#       3 plt.plot(history.history['val_loss'], label = 'valid_loss')
#       4 plt.title("Loss of model on Dogs and Cats classification")
#       5 plt.xlabel("Epochs")
#
# NameError: name 'history' is not defined

# %%
valid_data,valid_label =  next(valid_aug_gen)

def get_label_name(prediction):
    return "dog" if prediction < 0.5 else "cat"

plt.figure(figsize = (20,8))
nrow = 2
ncol = 5

for i,(img, label) in enumerate(zip(valid_data[:10], valid_label[:10])):
    
    predict_result = cnn_model.predict(np.expand_dims(img, axis = 0))[:,1]
    predict_result = get_label_name(predict_result[0])
    ground_truth = get_label_name(label[1])
    
    plt.subplot(nrow, ncol, i+1)
    plt.imshow(img)
    plt.title(f"predict : {predict_result}, ground truth : {ground_truth}")
    plt.axis("off")

plt.show()

# %%
submission = pd.read_csv('sample_submission.csv')
submission['Predicted'] = cnn_model.predict(test_x)[:,1] 
submission.to_csv("submission_v5.csv",header = ["ID", "Predicted"], index = False)

# %%
from google.colab import files

files.download('submission_v5.csv')
